# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from mpl_toolkits.basemap import Basemap
import matplotlib
import matplotlib.pyplot as plt
import StamenTonerTilesAccess as STT
import requests
import StringIO
from PIL import Image

# from sklearn.neighbors import KernelDensity
# from sklearn.grid_search import GridSearchCV

# %%
# DON'T RUN THIS CELL UNLESS THE CRIME_DATA FILE IS LOST

# This is the URL for the Philly PD crime incidents 2006-present API, and the requested data is given as a csv
url = 'https://data.phila.gov/resource/sspu-uyfa.csv?'

# This is my identifier 
token = '$$app_token=r3XjAbgHWtqqrmZCcdIpEd97O'

# By default, a request only gets me 1000 points, but there are over 2 million. I set limit to 3 million
limit = '&$limit=3000000'

# The API allows me to select columns a priori
cols= '&$select='

# These are the columns I want
col1 = 'dispatch_date AS Date'
col2 = ',dispatch_time AS Time'
col3 = ',ucr_general AS CrimeCodeNo'
col4 = ',text_general_code AS CrimeCodeText'
col5 = ',point_x AS lon'
col6 = ',point_y AS lat'

try:
    # Append the url and request the data
    response = requests.get(url+token+limit+cols+col1+col2+col3+col4+col5+col6)
    
    # Make the response readable
    csvdata = StringIO.StringIO(response.content)
    
    # Store it in a dataframe
    df = pd.read_csv(csvdata)
    
    # Pickle the dataframe so we don't have to keep requesting each time we want to use the data,
    # we can just load using pd.read_pickle('crime_data')
    df.to_pickle('crime_data')

except requests.exceptions.RequestException as e:
    print e
    sys.exit(1)

# %%
# Read data from pickle if we are starting a new session
df = pd.read_pickle('crime_data')

# %%
df.head()
# Out:
#    CrimeCodeNo       CrimeCodeText        Date      Time        lat        lon
# 0          800      Other Assaults  2009-10-02  14:24:00        NaN        NaN
# 1         2600  All Other Offenses  2009-05-10  00:55:00        NaN        NaN
# 2          800      Other Assaults  2009-08-07  15:40:00        NaN        NaN
# 3         1500   Weapon Violations  2009-07-19  01:09:00  40.036389 -75.130477
# 4         2600  All Other Offenses  2009-06-25  00:14:00  39.969532 -75.166350

# %%
# First let's drop the data points which have no latitude or longitude

df = df.dropna()
df.head()
# Out:
#     CrimeCodeNo       CrimeCodeText        Date      Time        lat  \
# 3          1500   Weapon Violations  2009-07-19  01:09:00  40.036389
# 4          2600  All Other Offenses  2009-06-25  00:14:00  39.969532
# 5           600              Thefts  2015-04-25  12:50:00  39.940070
# 6           800      Other Assaults  2009-02-10  14:33:00  39.979586
# 12          600              Thefts  2015-10-06  18:18:00  39.976134
#
#           lon
# 3  -75.130477
# 4  -75.166350
# 5  -75.166412
# 6  -75.171149
# 12 -75.160229

# %%
# Next, let's identify the crime code numbers corresponding to the different offenses

df.groupby(['CrimeCodeNo','CrimeCodeText']).count()
# Out:
#                                                        Date    Time     lat  \
# CrimeCodeNo CrimeCodeText
# 100         Homicide - Criminal                        3188    3188    3188
#             Homicide - Gross Negligence                  11      11      11
#             Homicide - Justifiable                       41      41      41
# 200         Rape                                      10860   10860   10860
# 300         Robbery Firearm                           37898   37898   37898
#             Robbery No Firearm                        48507   48507   48507
# 400         Aggravated Assault Firearm                25895   25895   25895
#             Aggravated Assault No Firearm             64270   64270   64270
# 500         Burglary Non-Residential                  22100   22100   22100
#             Burglary Residential                      89670   89670   89670
# 600         Theft from Vehicle                       158636  158636  158636
#             Thefts                                   236874  236874  236874
# 700         Motor Vehicle Theft                       44462   44462   44462
#             Recovered Stolen Motor Vehicle            88130   88130   88130
# 800         Other Assaults                           257464  257464  257464
# 900         Arson                                      5309    5309    5309
# 1000        Forgery and Counterfeiting                 4651    4651    4651
# 1100        Fraud                                    104527  104527  104527
# 1200        Embezzlement                               4334    4334    4334
# 1300        Receiving Stolen Property                   738     738     738
# 1400        Vandalism/Criminal Mischief              187252  187252  187252
# 1500        Weapon Violations                         17460   17460   17460
# 1600        Prostitution and Commercialized Vice      12094   12094   12094
# 1700        Other Sex Offenses (Not Commercialized)   14520   14520   14520
# 1800        Narcotic / Drug Law Violations           130502  130502  130502
# 1900        Gambling Violations                         883     883     883
# 2000        Offenses Against Family and Children       1694    1694    1694
# 2100        DRIVING UNDER THE INFLUENCE               50088   50088   50088
# 2200        Liquor Law Violations                      5340    5340    5340
# 2300        Public Drunkenness                         4420    4420    4420
# 2400        Disorderly Conduct                        38997   38997   38997
# 2500        Vagrancy/Loitering                         6734    6734    6734
# 2600        All Other Offenses                       412901  412901  412901
#
#                                                         lon
# CrimeCodeNo CrimeCodeText
# 100         Homicide - Criminal                        3188
#             Homicide - Gross Negligence                  11
#             Homicide - Justifiable                       41
# 200         Rape                                      10860
# 300         Robbery Firearm                           37898
#             Robbery No Firearm                        48507
# 400         Aggravated Assault Firearm                25895
#             Aggravated Assault No Firearm             64270
# 500         Burglary Non-Residential                  22100
#             Burglary Residential                      89670
# 600         Theft from Vehicle                       158636
#             Thefts                                   236874
# 700         Motor Vehicle Theft                       44462
#             Recovered Stolen Motor Vehicle            88130
# 800         Other Assaults                           257464
# 900         Arson                                      5309
# 1000        Forgery and Counterfeiting                 4651
# 1100        Fraud                                    104527
# 1200        Embezzlement                               4334
# 1300        Receiving Stolen Property                   738
# 1400        Vandalism/Criminal Mischief              187252
# 1500        Weapon Violations                         17460
# 1600        Prostitution and Commercialized Vice      12094
# 1700        Other Sex Offenses (Not Commercialized)   14520
# 1800        Narcotic / Drug Law Violations           130502
# 1900        Gambling Violations                         883
# 2000        Offenses Against Family and Children       1694
# 2100        DRIVING UNDER THE INFLUENCE               50088
# 2200        Liquor Law Violations                      5340
# 2300        Public Drunkenness                         4420
# 2400        Disorderly Conduct                        38997
# 2500        Vagrancy/Loitering                         6734
# 2600        All Other Offenses                       412901

# %%
# We see that there are actually a large number of thefts. For now, let us focus on aggravated crimes like
# homicide, robbery, rape, assualt, burglary. These have crime codes 100-500 and 800
# Later, we can study motor vehicle thefts as well

# For now, we're also not going to care about time so we won't deal with this now. Later on, we can see how 
# crime changes based on times of the day

crime_df = df[(df.CrimeCodeNo<500) | (df.CrimeCodeNo==800)].drop('Time',axis=1)

# We can reset the index. This way, we won't run into problems later on when getting the year

crime_df = crime_df.reset_index()
crime_df.head()
# Out:
#    index  CrimeCodeNo       CrimeCodeText        Date        lat        lon
# 0      6          800      Other Assaults  2009-02-10  39.979586 -75.171149
# 1     28          800      Other Assaults  2015-08-23  39.995626 -75.125869
# 2     35          300  Robbery No Firearm  2015-11-13  40.020219 -75.077126
# 3     36          800      Other Assaults  2015-10-29  39.968878 -75.236743
# 4     52          300     Robbery Firearm  2015-11-05  39.986415 -75.169577

# %%
# For now, we are only interested in the year the crime took place
crime_df['Year'] = pd.Series([int(date[0:4]) for date in crime_df.Date])
crime_loc_df = crime_df[['lat','lon','Year']]
crime_loc_df.head()
# Out:
#          lat        lon  Year
# 0  39.979586 -75.171149  2009
# 1  39.995626 -75.125869  2015
# 2  40.020219 -75.077126  2015
# 3  39.968878 -75.236743  2015
# 4  39.986415 -75.169577  2015

# %%
# From the data, we get the boundaries so that we can plot on a map
### This portion was done by Heather Simpson ###

# Find Max and Min Latitude and Longitude value where crimes take place

latmax = crime_df['lat'].max()
latmin = crime_df['lat'].min()
lonmax = crime_df['lon'].max()
lonmin = crime_df['lon'].min()

# Get the correct regions of the map from StamenToner

delta_lat = latmax-latmin
delta_long = lonmax-lonmin
zoom = 14

a, bbox = STT.getImageCluster(latmin, lonmin, delta_lat*.8,  delta_long*.8, zoom)
xmin = bbox[0]
ymin = bbox[1]
xmax = bbox[2]
ymax = bbox[3]

# Save the map as a figure

fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)
plt.axis("off")
m = Basemap(
    llcrnrlon=xmin, llcrnrlat=ymin,
    urcrnrlon=xmax, urcrnrlat=ymax,
    projection='merc', ax=ax
)
m.imshow(a, alpha=1, interpolation='lanczos', origin='upper')
extent = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted())  #gets extent of bbox for just the plot (without the frame/padding), so we can save just the plot extent (no frame / axis), allowing us to overlay the images later    
plotname = 'philly_map.png'
plt.savefig(plotname, bbox_inches=extent) #save image of plot
plt.close()
# Out:
# Opening: http://tile.stamen.com/toner/14/4766/6197.png
# Opening: http://tile.stamen.com/toner/14/4766/6198.png
# Opening: http://tile.stamen.com/toner/14/4766/6199.png
# Opening: http://tile.stamen.com/toner/14/4766/6200.png
# Opening: http://tile.stamen.com/toner/14/4766/6201.png
# Opening: http://tile.stamen.com/toner/14/4766/6202.png
# Opening: http://tile.stamen.com/toner/14/4766/6203.png
# Opening: http://tile.stamen.com/toner/14/4766/6204.png
# Opening: http://tile.stamen.com/toner/14/4766/6205.png
# Opening: http://tile.stamen.com/toner/14/4766/6206.png
# Opening: http://tile.stamen.com/toner/14/4766/6207.png
# Opening: http://tile.stamen.com/toner/14/4766/6208.png
# Opening: http://tile.stamen.com/toner/14/4766/6209.png
# Opening: http://tile.stamen.com/toner/14/4766/6210.png
# Opening: http://tile.stamen.com/toner/14/4767/6197.png
# Opening: http://tile.stamen.com/toner/14/4767/6198.png
# Opening: http://tile.stamen.com/toner/14/4767/6199.png
# Opening: http://tile.stamen.com/toner/14/4767/6200.png
# Opening: http://tile.stamen.com/toner/14/4767/6201.png
# Opening: http://tile.stamen.com/toner/14/4767/6202.png
# Opening: http://tile.stamen.com/toner/14/4767/6203.png
# Opening: http://tile.stamen.com/toner/14/4767/6204.png
# Opening: http://tile.stamen.com/toner/14/4767/6205.png
# Opening: http://tile.stamen.com/toner/14/4767/6206.png
# Opening: http://tile.stamen.com/toner/14/4767/6207.png
# Opening: http://tile.stamen.com/toner/14/4767/6208.png
# Opening: http://tile.stamen.com/toner/14/4767/6209.png
# Opening: http://tile.stamen.com/toner/14/4767/6210.png
# Opening: http://tile.stamen.com/toner/14/4768/6197.png
# Opening: http://tile.stamen.com/toner/14/4768/6198.png
# Opening: http://tile.stamen.com/toner/14/4768/6199.png
# Opening: http://tile.stamen.com/toner/14/4768/6200.png
# Opening: http://tile.stamen.com/toner/14/4768/6201.png
# Opening: http://tile.stamen.com/toner/14/4768/6202.png
# Opening: http://tile.stamen.com/toner/14/4768/6203.png
# Opening: http://tile.stamen.com/toner/14/4768/6204.png
# Opening: http://tile.stamen.com/toner/14/4768/6205.png
# Opening: http://tile.stamen.com/toner/14/4768/6206.png
# Opening: http://tile.stamen.com/toner/14/4768/6207.png
# Opening: http://tile.stamen.com/toner/14/4768/6208.png
# Opening: http://tile.stamen.com/toner/14/4768/6209.png
# Opening: http://tile.stamen.com/toner/14/4768/6210.png
# Opening: http://tile.stamen.com/toner/14/4769/6197.png
# Opening: http://tile.stamen.com/toner/14/4769/6198.png
# Opening: http://tile.stamen.com/toner/14/4769/6199.png
# Opening: http://tile.stamen.com/toner/14/4769/6200.png
# Opening: http://tile.stamen.com/toner/14/4769/6201.png
# Opening: http://tile.stamen.com/toner/14/4769/6202.png
# Opening: http://tile.stamen.com/toner/14/4769/6203.png
# Opening: http://tile.stamen.com/toner/14/4769/6204.png
# Opening: http://tile.stamen.com/toner/14/4769/6205.png
# Opening: http://tile.stamen.com/toner/14/4769/6206.png
# Opening: http://tile.stamen.com/toner/14/4769/6207.png
# Opening: http://tile.stamen.com/toner/14/4769/6208.png
# Opening: http://tile.stamen.com/toner/14/4769/6209.png
# Opening: http://tile.stamen.com/toner/14/4769/6210.png
# Opening: http://tile.stamen.com/toner/14/4770/6197.png
# Opening: http://tile.stamen.com/toner/14/4770/6198.png
# Opening: http://tile.stamen.com/toner/14/4770/6199.png
# Opening: http://tile.stamen.com/toner/14/4770/6200.png
# Opening: http://tile.stamen.com/toner/14/4770/6201.png
# Opening: http://tile.stamen.com/toner/14/4770/6202.png
# Opening: http://tile.stamen.com/toner/14/4770/6203.png
# Opening: http://tile.stamen.com/toner/14/4770/6204.png
# Opening: http://tile.stamen.com/toner/14/4770/6205.png
# Opening: http://tile.stamen.com/toner/14/4770/6206.png
# Opening: http://tile.stamen.com/toner/14/4770/6207.png
# Opening: http://tile.stamen.com/toner/14/4770/6208.png
# Opening: http://tile.stamen.com/toner/14/4770/6209.png
# Opening: http://tile.stamen.com/toner/14/4770/6210.png
# Opening: http://tile.stamen.com/toner/14/4771/6197.png
# Opening: http://tile.stamen.com/toner/14/4771/6198.png
# Opening: http://tile.stamen.com/toner/14/4771/6199.png
# Opening: http://tile.stamen.com/toner/14/4771/6200.png
# Opening: http://tile.stamen.com/toner/14/4771/6201.png
# Opening: http://tile.stamen.com/toner/14/4771/6202.png
# Opening: http://tile.stamen.com/toner/14/4771/6203.png
# Opening: http://tile.stamen.com/toner/14/4771/6204.png
# Opening: http://tile.stamen.com/toner/14/4771/6205.png
# Opening: http://tile.stamen.com/toner/14/4771/6206.png
# Opening: http://tile.stamen.com/toner/14/4771/6207.png
# Opening: http://tile.stamen.com/toner/14/4771/6208.png
# Opening: http://tile.stamen.com/toner/14/4771/6209.png
# Opening: http://tile.stamen.com/toner/14/4771/6210.png
# Opening: http://tile.stamen.com/toner/14/4772/6197.png
# Opening: http://tile.stamen.com/toner/14/4772/6198.png
# Opening: http://tile.stamen.com/toner/14/4772/6199.png
# Opening: http://tile.stamen.com/toner/14/4772/6200.png
# Opening: http://tile.stamen.com/toner/14/4772/6201.png
# Opening: http://tile.stamen.com/toner/14/4772/6202.png
# Opening: http://tile.stamen.com/toner/14/4772/6203.png
# Opening: http://tile.stamen.com/toner/14/4772/6204.png
# Opening: http://tile.stamen.com/toner/14/4772/6205.png
# Opening: http://tile.stamen.com/toner/14/4772/6206.png
# Opening: http://tile.stamen.com/toner/14/4772/6207.png
# Opening: http://tile.stamen.com/toner/14/4772/6208.png
# Opening: http://tile.stamen.com/toner/14/4772/6209.png
# Opening: http://tile.stamen.com/toner/14/4772/6210.png
# Opening: http://tile.stamen.com/toner/14/4773/6197.png
# Opening: http://tile.stamen.com/toner/14/4773/6198.png
# Opening: http://tile.stamen.com/toner/14/4773/6199.png
# Opening: http://tile.stamen.com/toner/14/4773/6200.png
# Opening: http://tile.stamen.com/toner/14/4773/6201.png
# Opening: http://tile.stamen.com/toner/14/4773/6202.png
# Opening: http://tile.stamen.com/toner/14/4773/6203.png
# Opening: http://tile.stamen.com/toner/14/4773/6204.png
# Opening: http://tile.stamen.com/toner/14/4773/6205.png
# Opening: http://tile.stamen.com/toner/14/4773/6206.png
# Opening: http://tile.stamen.com/toner/14/4773/6207.png
# Opening: http://tile.stamen.com/toner/14/4773/6208.png
# Opening: http://tile.stamen.com/toner/14/4773/6209.png
# Opening: http://tile.stamen.com/toner/14/4773/6210.png
# Opening: http://tile.stamen.com/toner/14/4774/6197.png
# Opening: http://tile.stamen.com/toner/14/4774/6198.png
# Opening: http://tile.stamen.com/toner/14/4774/6199.png
# Opening: http://tile.stamen.com/toner/14/4774/6200.png
# Opening: http://tile.stamen.com/toner/14/4774/6201.png
# Opening: http://tile.stamen.com/toner/14/4774/6202.png
# Opening: http://tile.stamen.com/toner/14/4774/6203.png
# Opening: http://tile.stamen.com/toner/14/4774/6204.png
# Opening: http://tile.stamen.com/toner/14/4774/6205.png
# Opening: http://tile.stamen.com/toner/14/4774/6206.png
# Opening: http://tile.stamen.com/toner/14/4774/6207.png
# Opening: http://tile.stamen.com/toner/14/4774/6208.png
# Opening: http://tile.stamen.com/toner/14/4774/6209.png
# Opening: http://tile.stamen.com/toner/14/4774/6210.png
# Opening: http://tile.stamen.com/toner/14/4775/6197.png
# Opening: http://tile.stamen.com/toner/14/4775/6198.png
# Opening: http://tile.stamen.com/toner/14/4775/6199.png
# Opening: http://tile.stamen.com/toner/14/4775/6200.png
# Opening: http://tile.stamen.com/toner/14/4775/6201.png
# Opening: http://tile.stamen.com/toner/14/4775/6202.png
# Opening: http://tile.stamen.com/toner/14/4775/6203.png
# Opening: http://tile.stamen.com/toner/14/4775/6204.png
# Opening: http://tile.stamen.com/toner/14/4775/6205.png
# Opening: http://tile.stamen.com/toner/14/4775/6206.png
# Opening: http://tile.stamen.com/toner/14/4775/6207.png
# Opening: http://tile.stamen.com/toner/14/4775/6208.png
# Opening: http://tile.stamen.com/toner/14/4775/6209.png
# Opening: http://tile.stamen.com/toner/14/4775/6210.png
# Opening: http://tile.stamen.com/toner/14/4776/6197.png
# Opening: http://tile.stamen.com/toner/14/4776/6198.png
# Opening: http://tile.stamen.com/toner/14/4776/6199.png
# Opening: http://tile.stamen.com/toner/14/4776/6200.png
# Opening: http://tile.stamen.com/toner/14/4776/6201.png
# Opening: http://tile.stamen.com/toner/14/4776/6202.png
# Opening: http://tile.stamen.com/toner/14/4776/6203.png
# Opening: http://tile.stamen.com/toner/14/4776/6204.png
# Opening: http://tile.stamen.com/toner/14/4776/6205.png
# Opening: http://tile.stamen.com/toner/14/4776/6206.png
# Opening: http://tile.stamen.com/toner/14/4776/6207.png
# Opening: http://tile.stamen.com/toner/14/4776/6208.png
# Opening: http://tile.stamen.com/toner/14/4776/6209.png
# Opening: http://tile.stamen.com/toner/14/4776/6210.png
# Opening: http://tile.stamen.com/toner/14/4777/6197.png
# Opening: http://tile.stamen.com/toner/14/4777/6198.png
# Opening: http://tile.stamen.com/toner/14/4777/6199.png
# Opening: http://tile.stamen.com/toner/14/4777/6200.png
# Opening: http://tile.stamen.com/toner/14/4777/6201.png
# Opening: http://tile.stamen.com/toner/14/4777/6202.png
# Opening: http://tile.stamen.com/toner/14/4777/6203.png
# Opening: http://tile.stamen.com/toner/14/4777/6204.png
# Opening: http://tile.stamen.com/toner/14/4777/6205.png
# Opening: http://tile.stamen.com/toner/14/4777/6206.png
# Opening: http://tile.stamen.com/toner/14/4777/6207.png
# Opening: http://tile.stamen.com/toner/14/4777/6208.png
# Opening: http://tile.stamen.com/toner/14/4777/6209.png
# Opening: http://tile.stamen.com/toner/14/4777/6210.png

# %%
# %matplotlib inline  

for year in np.arange(2006,2016):
    
    # Get the crime data for a particular year
    
    crime_given_year = crime_loc_df[crime_loc_df.Year==year]
    
    # Get a kernel density plot of the corresponding year's data using seaborn
    
    fig = plt.figure(figsize=(12,12))
    ax = fig.add_subplot(111)
    plt.axis("off")
    sns.kdeplot(crime_given_year.lon.values, crime_given_year.lat.values, shade=True) 
    extent = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted()) #gets extent of bbox for just the plot (without the frame/padding), so we can save just the plot extent (no frame / axis), allowing us to overlay the images later
    plotname = 'philly_contour'+str(year)+'.png'
    plt.savefig(plotname, bbox_inches=extent) #save image of plot
    plt.close()
    
    # Overlay the kernel density plot with the map. This portion was done by Heather Simpson
    
    
    map_img = Image.open('philly_map.png')
    map_img = map_img.convert("RGBA")
    datas = map_img.getdata()

    newData = []
    for item in datas:
        if item[0] >200 and item[1] >200 and item[2] > 200:
            newData.append((item[0], item[1], item[2], 0))
        else:
            newData.append(item)
    map_img.putdata(newData)

    contourname = 'philly_contour'+str(year)+'.png'
    contour_img = Image.open(contourname)

    fig = plt.figure(figsize=(13,13))
    ax = plt.subplot(111)
    extent = xmin, xmax, ymin, ymax #note xmin, xmax, ymin, ymax come from tile map at beginning of script
    contourlayer = plt.imshow(contour_img,interpolation="nearest",extent=extent)
    plt.hold(True)
    map_layer = plt.imshow(map_img, alpha=1, interpolation='bilinear',extent=extent)
    plt.xlabel('Longitude',fontsize=20)
    plt.ylabel('Latitude',fontsize=20)
    plt.title('Philadelphia crime heat map for the year ' + str(year),fontsize=30)
    plt.show()
    extent = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted()) 
    plotname = 'philly_overlay.png' 
    plt.savefig(plotname, bbox_inches=extent)
    plt.close()
